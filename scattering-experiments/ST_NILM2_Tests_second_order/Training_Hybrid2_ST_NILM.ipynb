# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#%reload_ext tensorboard
#%tensorboard --logdir drive/MyDrive/Scattering/tmp/CNN/P100_3/logs/validation

# %%
# !pip install tensorflow==2.4.0
# !pip install keras==2.4.0
# !pip install kymatio
# !pip install tqdm
# !pip install iterative-stratification
# !pip install scikit-multilearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.4.0 (from versions: 2.5.0, 2.5.1, 2.5.2, 2.5.3, 2.6.0rc0, 2.6.0rc1, 2.6.0rc2, 2.6.0, 2.6.1, 2.6.2, 2.6.3, 2.6.4, 2.6.5, 2.7.0rc0, 2.7.0rc1, 2.7.0, 2.7.1, 2.7.2, 2.7.3, 2.7.4, 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.9.3, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0, 2.10.1, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0, 2.11.1, 2.12.0rc0, 2.12.0rc1, 2.12.0)
# ERROR: No matching distribution found for tensorflow==2.4.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras==2.4.0 in /usr/local/lib/python3.9/dist-packages (2.4.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.9/dist-packages (from keras==2.4.0) (1.10.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.9/dist-packages (from keras==2.4.0) (1.19.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from keras==2.4.0) (6.0)
# Requirement already satisfied: tensorflow>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from keras==2.4.0) (2.5.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.9/dist-packages (from keras==2.4.0) (3.1.0)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->keras==2.4.0) (0.4.0)
# Requirement already satisfied: grpcio~=1.34.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->keras==2.4.0) (1.34.1)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->keras==2.4.0) (1.6.3)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->keras==2.4.0) (1.1.2)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->keras==2.4.0) (1.15.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->keras==2.4.0) (2.5.0)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->keras==2.4.0) (0.15.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->keras==2.4.0) (1.1.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->keras==2.4.0) (0.2.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->keras==2.4.0) (3.3.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->keras==2.4.0) (1.12.1)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->keras==2.4.0) (2.11.2)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->keras==2.4.0) (0.40.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->keras==2.4.0) (3.7.4.3)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->keras==2.4.0) (2.5.0.dev2021032900)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->keras==2.4.0) (1.12)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.2.0->keras==2.4.0) (3.19.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard~=2.5->tensorflow>=2.2.0->keras==2.4.0) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard~=2.5->tensorflow>=2.2.0->keras==2.4.0) (2.16.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard~=2.5->tensorflow>=2.2.0->keras==2.4.0) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard~=2.5->tensorflow>=2.2.0->keras==2.4.0) (67.6.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard~=2.5->tensorflow>=2.2.0->keras==2.4.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard~=2.5->tensorflow>=2.2.0->keras==2.4.0) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard~=2.5->tensorflow>=2.2.0->keras==2.4.0) (3.4.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard~=2.5->tensorflow>=2.2.0->keras==2.4.0) (2.2.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow>=2.2.0->keras==2.4.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow>=2.2.0->keras==2.4.0) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow>=2.2.0->keras==2.4.0) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow>=2.2.0->keras==2.4.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow>=2.2.0->keras==2.4.0) (6.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.2.0->keras==2.4.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.2.0->keras==2.4.0) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.2.0->keras==2.4.0) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.2.0->keras==2.4.0) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.5->tensorflow>=2.2.0->keras==2.4.0) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.5->tensorflow>=2.2.0->keras==2.4.0) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow>=2.2.0->keras==2.4.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow>=2.2.0->keras==2.4.0) (3.2.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kymatio in /usr/local/lib/python3.9/dist-packages (0.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from kymatio) (1.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from kymatio) (1.19.5)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.9/dist-packages (from kymatio) (1.4.4)
# Requirement already satisfied: configparser in /usr/local/lib/python3.9/dist-packages (from kymatio) (5.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from kymatio) (23.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (4.65.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: iterative-stratification in /usr/local/lib/python3.9/dist-packages (0.1.7)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from iterative-stratification) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from iterative-stratification) (1.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from iterative-stratification) (1.19.5)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->iterative-stratification) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->iterative-stratification) (3.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-multilearn in /usr/local/lib/python3.9/dist-packages (0.2.0)

# %%
from sklearn.preprocessing import MaxAbsScaler
from sklearn.model_selection import train_test_split, KFold
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
import numpy as np
import os
import pickle
import sys
sys.path.append("drive/MyDrive/Scattering_Novo/src")
from DataHandler import DataHandler
from ModelHandler import ModelHandler
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold
from skmultilearn.model_selection import iterative_train_test_split
from sklearn.model_selection import KFold
from sklearn.utils.class_weight import compute_class_weight, compute_sample_weight
 
configs = {
    "N_GRIDS": 5, 
    "SIGNAL_BASE_LENGTH": 12800, 
    "N_CLASS": 26, 
    "USE_NO_LOAD": False, 
    "USE_HAND_AUGMENTATION": False,
    "MARGIN_RATIO": 0.15, 
    "DATASET_PATH": "drive/MyDrive/Scattering_Novo/dataset_original/Synthetic_Full_iHall.hdf5",
    "TRAIN_SIZE": 0.9,
    "FOLDER_PATH": "drive/MyDrive/DeSpaWN-main/extracted_features/without_data_augmentation/Full_Dataset/", 
    "FOLDER_DATA_PATH": "drive/MyDrive/DeSpaWN-main/extracted_features/without_data_augmentation/Full_Dataset/", 
    "TESTS_FOLDER": 'drive/MyDrive/Scattering_Novo/results_second_order/',
    "FEATURES_FILE_NAME": "features.mat",
    "N_EPOCHS_TRAINING": 500,
    "PERCENTUAL": 0.25,
    "INITIAL_EPOCH": 0,
    "TOTAL_MAX_EPOCHS": 5000,
    "SNRdb": None # Nível de ruído em db
}

def freeze(model, task_name='classification'):
    for layer in model.layers:
        if task_name in layer.name:
            layer.trainable = True
        else:
            layer.trainable = False

    for layer in model.layers:
        print(layer.name, layer.trainable)

    return model

def calculating_class_weights(y_true):
    '''
        Source: https://stackoverflow.com/questions/48485870/multi-label-classification-with-class-weights-in-keras
    '''
    from sklearn.utils.class_weight import compute_class_weight
    number_dim = np.shape(y_true)[1]
    weights = np.empty([number_dim, 2])
    for i in range(number_dim):
        weights[i] = compute_class_weight(class_weight='balanced', classes=[0.,1.], y=y_true[:, i])
    return weights


def reduce_dataset(X_all,ydet_all,ytype_all,yclass_all,percentual):
    import numpy as np
    max_index = int(percentual*X_all.shape[0])
    np.random.seed(100)
    index = np.random.randint(max_index,size=(max_index-1))
    X_all = X_all[index]
    ydet_all = ydet_all[index]
    ytype_all = ytype_all[index]
    yclass_all = yclass_all[index]

    return X_all,ydet_all,ytype_all,yclass_all

ngrids = configs["N_GRIDS"]
signalBaseLength = configs["SIGNAL_BASE_LENGTH"]
trainSize = configs["TRAIN_SIZE"]
folderDataPath = configs["FOLDER_DATA_PATH"]
 
dataHandler = DataHandler(configs)

# Se não tiver os dados no formato necessário já organizados, faz a organização
if not os.path.isfile(folderDataPath + "data.p"):
    print("Sorted data not found, creating new file...")
    x, ydet, yclass, ytype, ygroup = dataHandler.loadData(hand_augmentation=configs["USE_HAND_AUGMENTATION"], SNR=configs["SNRdb"])
    print("Data loaded")

    data_mskf = MultilabelStratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    strat_classes = np.max(yclass, axis=1)
    train_index, test_index = next(data_mskf.split(x, strat_classes))

    y_train = {
        "detection": ydet[train_index], 
        "type": ytype[train_index], 
        "classification": yclass[train_index], 
        "group": ygroup[train_index]
    }
    
    y_test = {
        "detection": ydet[test_index], 
        "type": ytype[test_index], 
        "classification": yclass[test_index], 
        "group": ygroup[test_index]
    }
    
    dict_data = {
        "x_train": x[train_index], 
        "x_test": x[test_index], 
        "y_train": y_train, 
        "y_test": y_test
    }

    print("Data sorted")

    try:
        os.mkdir(folderDataPath)
    except:
        pass

    pickle.dump(dict_data, open(folderDataPath + "data.p", "wb"))
    print("Data stored")
else:
    dict_data = pickle.load(open(folderDataPath + "data.p", "rb"))



modelHandler = ModelHandler(configs)
 
X_all = dict_data["x_train"]
ydet_all = dict_data["y_train"]["detection"]
ytype_all = dict_data["y_train"]["type"]
yclass_all = dict_data["y_train"]["classification"]

if configs["PERCENTUAL"]!=1:
        X_all,ydet_all,ytype_all,yclass_all = reduce_dataset(X_all,ydet_all,ytype_all,yclass_all,configs["PERCENTUAL"])

print(X_all.shape)
print(dict_data["x_test"].shape)
# Out:
# (1892, 16640, 1)
# (841, 16640, 1)

# %%
from kymatio.numpy import Scattering1D as ScatNumpy
from kymatio.datasets import fetch_fsdd

J=10
Q=2

scattering = ScatNumpy(J, X_all.shape[1], Q)

#Sx = scattering(X_all[10])


meta = scattering.meta()
order0 = np.where(meta['order'] == 0)
order1 = np.where(meta['order'] == 1)
order2 = np.where(meta['order'] == 2)


print("ZEro order inits on position " + str(order0[0][0]) + " and finishes at " + str(order0[0][-1]))
print("First order inits on position " + str(order1[0][0]) + " and finishes at " + str(order1[0][-1]))
print("Second order inits on position " + str(order2[0][0]) + " and finishes at " + str(order2[0][-1]))

start1 = order1[0][0]
end1   = order1[0][-1]
start2 = order2[0][0]
end2   = order2[0][-1]
start0 = order0[0][0]
end0   = order0[0][-1]

del meta, scattering, order1, order2
# Out:
# ZEro order inits on position 0 and finishes at 0
# First order inits on position 1 and finishes at 21
# Second order inits on position 22 and finishes at 109

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, GlobalAveragePooling1D, Flatten, MaxPool1D, GlobalMaxPooling1D
from tensorflow.keras.models import Model
from kymatio.keras import Scattering1D

def buildBaseScattering(input_shape):
    '''
        Source: https://github.com/kymatio/kymatio/blob/master/examples/1d/classif_keras.py
    '''
    log_eps = 1e-6
    
    input = Input(shape=(input_shape,))
    x = Scattering1D(10, 10, max_order=1)(input) 

    unmapped_len = int(0.15 * (x.shape[2] / 1.3))
    grid_len = int((x.shape[2] - 2 * unmapped_len) / 5)

    print(f"X: {x.shape[2]}, Unmapped: {unmapped_len}, Grid: {grid_len}")

    left = Lambda(lambda x: x[..., :, : unmapped_len], name='left')(x)
    center = Lambda(lambda x: x[..., :, unmapped_len : x.shape[2] - unmapped_len], name='center')(x)
    right = Lambda(lambda x: x[..., :, x.shape[2] - unmapped_len :], name='right')(x)

    g1 = Lambda(lambda x: x[..., :, :grid_len], name='g1')(center)
    g2 = Lambda(lambda x: x[..., :, grid_len:2*grid_len], name='g2')(center)
    g3 = Lambda(lambda x: x[..., :, 2*grid_len:3*grid_len], name='g3')(center)
    g4 = Lambda(lambda x: x[..., :, 3*grid_len:4*grid_len], name='g4')(center)
    g5 = Lambda(lambda x: x[..., :, 4*grid_len:], name='g5')(center)


    leftav = tf.keras.backend.max(left, axis=2)
    g1av   = tf.keras.backend.max(g1, axis=2)
    g2av   = tf.keras.backend.max(g2, axis=2)
    g3av   = tf.keras.backend.max(g3, axis=2)
    g4av   = tf.keras.backend.max(g4, axis=2)
    g5av   = tf.keras.backend.max(g5, axis=2)
    rightav = tf.keras.backend.max(right, axis=2)
    

    x_type = tf.concat([(g1av-leftav), (g2av-leftav), (g3av-g1av), (g4av-g2av), (g5av-g3av), (rightav-g4av), (rightav-g5av) ], axis=1)

    
    x_class = tf.concat([leftav, g1av, g2av, g3av, g4av, g5av, rightav], axis=1)
  
    x_type = Flatten()(x_type)
    x_class = Flatten()(x_class)



    model = Model(inputs = input, outputs=[x_type, x_class])

    return model


def buildBaseScattering_2order(input_shape, start1=start1, end1=end1, start2=start2):
    '''
        Source: https://github.com/kymatio/kymatio/blob/master/examples/1d/classif_keras.py
    '''
    log_eps = 1e-6
    
    input = Input(shape=(input_shape,))
    scattering = Scattering1D(10, 2, max_order=2)
    x = scattering(input)

    print(x)
    print(x.shape)

    # separando os coeficientes de primeira e segunda ordem
    x1 = x[..., 1:end1, :]
    x2 = x[..., end1:, :]

    x1 = Lambda(lambda x1: tf.math.log(tf.abs(x1) + log_eps))(x1)
    x2 = Lambda(lambda x2: tf.math.log(tf.abs(x2) + log_eps))(x2)

    print("Shape of Sx: " + str(x.shape))
    print("Shape of Sx1: " + str(x1.shape))
    print("Shape of Sx2: " + str(x2.shape))


    unmapped_len1 = int(0.15 * (x1.shape[2] / 1.3))
    grid_len1 = int((x1.shape[2] - 2 * unmapped_len1) / 5)

    unmapped_len2 = int(0.15 * (x2.shape[2] / 1.3))
    grid_len2 = int((x2.shape[2] - 2 * unmapped_len2) / 5)

    left1 = Lambda(lambda x1: x1[..., :, : unmapped_len1], name='left1')(x1)
    center1 = Lambda(lambda x1: x1[..., :, unmapped_len1 : x1.shape[2] - unmapped_len1], name='center1')(x1)
    right1 = Lambda(lambda x1: x1[..., :, x1.shape[2] - unmapped_len1 :], name='right1')(x1)

    left2 = Lambda(lambda x2: x2[..., :, : unmapped_len2], name='left2')(x2)
    center2 = Lambda(lambda x2: x2[..., :, unmapped_len2 : x2.shape[2] - unmapped_len2], name='center2')(x2)
    right2 = Lambda(lambda x2: x2[..., :, x2.shape[2] - unmapped_len2 :], name='right2')(x2)


    g11 = Lambda(lambda x1: x1[..., :, :grid_len1], name='g11')(center1)
    g21 = Lambda(lambda x1: x1[..., :, grid_len1:2*grid_len1], name='g21')(center1)
    g31 = Lambda(lambda x1: x1[..., :, 2*grid_len1:3*grid_len1], name='g31')(center1)
    g41 = Lambda(lambda x1: x1[..., :, 3*grid_len1:4*grid_len1], name='g41')(center1)
    g51 = Lambda(lambda x1: x1[..., :, 4*grid_len1:], name='g51')(center1)


    leftav1 = tf.keras.backend.max(left1, axis=2)
    g1av1   = tf.keras.backend.max(g11, axis=2)
    g2av1   = tf.keras.backend.max(g21, axis=2)
    g3av1   = tf.keras.backend.max(g31, axis=2)
    g4av1   = tf.keras.backend.max(g41, axis=2)
    g5av1   = tf.keras.backend.max(g51, axis=2)
    rightav1 = tf.keras.backend.max(right1, axis=2)


    g12 = Lambda(lambda x2: x2[..., :, :grid_len2], name='g12')(center2)
    g22 = Lambda(lambda x2: x2[..., :, grid_len2:2*grid_len2], name='g22')(center2)
    g32 = Lambda(lambda x2: x2[..., :, 2*grid_len2:3*grid_len2], name='g32')(center2)
    g42 = Lambda(lambda x2: x2[..., :, 3*grid_len2:4*grid_len2], name='g42')(center2)
    g52 = Lambda(lambda x2: x2[..., :, 4*grid_len2:], name='g52')(center2)


    leftav2 = tf.keras.backend.max(left2, axis=2)
    g1av2   = tf.keras.backend.max(g12, axis=2)
    g2av2   = tf.keras.backend.max(g22, axis=2)
    g3av2   = tf.keras.backend.max(g32, axis=2)
    g4av2   = tf.keras.backend.max(g42, axis=2)
    g5av2   = tf.keras.backend.max(g52, axis=2)
    rightav2 = tf.keras.backend.max(right2, axis=2)

    
    
    x_type = tf.concat([(g1av1-leftav1), (g2av1-leftav1), (g3av1-g1av1), (g4av1-g2av1), (g5av1-g3av1), (rightav1-g4av1), (rightav1-g5av1), (g1av2-leftav2), (g2av2-leftav2), (g3av2-g1av2), (g4av2-g2av2), (g5av2-g3av2), (rightav2-g4av2), (rightav2-g5av2) ], axis=1)


    x_class = tf.concat([leftav1, g1av1, g2av1, g3av1, g4av1, g5av1, rightav1, leftav2, g1av2, g2av2, g3av2, g4av2, g5av2, rightav2], axis=1)
  
    x_type = Flatten()(x_type)
    x_class = Flatten()(x_class)

    # ================================================================

    # x = GlobalAveragePooling1D()(x)

    model = Model(inputs = input, outputs=[x_type, x_class])

    return model


def buildBaseScattering_hybrid(input_shape, start1=start1, end1=end1, start2=start2):
    '''
        Source: https://github.com/kymatio/kymatio/blob/master/examples/1d/classif_keras.py
    '''
    log_eps = 1e-6
    
    input = Input(shape=(input_shape,))
    scattering = Scattering1D(10, 2, max_order=2)
    x = scattering(input)

    print(x)
    print(x.shape)

    # separando os coeficientes de primeira e segunda ordem
    x1 = x[..., 1:end1, :]
    x2 = x[..., end1:, :]

    x1 = Lambda(lambda x1: tf.math.log(tf.abs(x1) + log_eps))(x1)
    x2 = Lambda(lambda x2: tf.math.log(tf.abs(x2) + log_eps))(x2)

    print("Shape of Sx: " + str(x.shape))
    print("Shape of Sx1: " + str(x1.shape))
    print("Shape of Sx2: " + str(x2.shape))


    unmapped_len1 = int(0.15 * (x1.shape[2] / 1.3))
    grid_len1 = int((x1.shape[2] - 2 * unmapped_len1) / 5)

    unmapped_len2 = int(0.15 * (x2.shape[2] / 1.3))
    grid_len2 = int((x2.shape[2] - 2 * unmapped_len2) / 5)

    left1 = Lambda(lambda x1: x1[..., :, : unmapped_len1], name='left1')(x1)
    center1 = Lambda(lambda x1: x1[..., :, unmapped_len1 : x1.shape[2] - unmapped_len1], name='center1')(x1)
    right1 = Lambda(lambda x1: x1[..., :, x1.shape[2] - unmapped_len1 :], name='right1')(x1)

    left2 = Lambda(lambda x2: x2[..., :, : unmapped_len2], name='left2')(x2)
    center2 = Lambda(lambda x2: x2[..., :, unmapped_len2 : x2.shape[2] - unmapped_len2], name='center2')(x2)
    right2 = Lambda(lambda x2: x2[..., :, x2.shape[2] - unmapped_len2 :], name='right2')(x2)


    g11 = Lambda(lambda x1: x1[..., :, :grid_len1], name='g11')(center1)
    g21 = Lambda(lambda x1: x1[..., :, grid_len1:2*grid_len1], name='g21')(center1)
    g31 = Lambda(lambda x1: x1[..., :, 2*grid_len1:3*grid_len1], name='g31')(center1)
    g41 = Lambda(lambda x1: x1[..., :, 3*grid_len1:4*grid_len1], name='g41')(center1)
    g51 = Lambda(lambda x1: x1[..., :, 4*grid_len1:], name='g51')(center1)


    leftav1 = tf.keras.backend.max(left1, axis=2)
    g1av1   = tf.keras.backend.max(g11, axis=2)
    g2av1   = tf.keras.backend.max(g21, axis=2)
    g3av1   = tf.keras.backend.max(g31, axis=2)
    g4av1   = tf.keras.backend.max(g41, axis=2)
    g5av1   = tf.keras.backend.max(g51, axis=2)
    rightav1 = tf.keras.backend.max(right1, axis=2)


    g12 = Lambda(lambda x2: x2[..., :, :grid_len2], name='g12')(center2)
    g22 = Lambda(lambda x2: x2[..., :, grid_len2:2*grid_len2], name='g22')(center2)
    g32 = Lambda(lambda x2: x2[..., :, 2*grid_len2:3*grid_len2], name='g32')(center2)
    g42 = Lambda(lambda x2: x2[..., :, 3*grid_len2:4*grid_len2], name='g42')(center2)
    g52 = Lambda(lambda x2: x2[..., :, 4*grid_len2:], name='g52')(center2)


    leftav2 = tf.keras.backend.max(left2, axis=2)
    g1av2   = tf.keras.backend.max(g12, axis=2)
    g2av2   = tf.keras.backend.max(g22, axis=2)
    g3av2   = tf.keras.backend.max(g32, axis=2)
    g4av2   = tf.keras.backend.max(g42, axis=2)
    g5av2   = tf.keras.backend.max(g52, axis=2)
    rightav2 = tf.keras.backend.max(right2, axis=2)

    
    
    x_type = tf.concat([(g1av1-leftav1), (g2av1-leftav1), (g3av1-g1av1), (g4av1-g2av1), (g5av1-g3av1), (rightav1-g4av1), (rightav1-g5av1), (g1av2-leftav2), (g2av2-leftav2), (g3av2-g1av2), (g4av2-g2av2), (g5av2-g3av2), (rightav2-g4av2), (rightav2-g5av2) ], axis=1)


    x_class = tf.concat([(g1av1-leftav1), (g2av1 - leftav1), (g3av1-g1av1),(g4av1-g2av1), (g5av1-g3av1), (rightav1-g4av1), (rightav1-g5av1)], axis=1)

    x_type = Flatten()(x_type)
    x_class = Flatten()(x_class)



    model = Model(inputs = input, outputs=[x_type, x_class])

    return model

def buildBaseScattering_hybrid2(input_shape, start1=start1, end1=end1, start2=start2):
    '''
        Source: https://github.com/kymatio/kymatio/blob/master/examples/1d/classif_keras.py
    '''
    log_eps = 1e-6
    
    input = Input(shape=(input_shape,))
    scattering = Scattering1D(10, 2, max_order=2)
    x = scattering(input)

    print(x)
    print(x.shape)

    x1 = x[..., 1:end1, :]
    x2 = x[..., end1:, :]


    print("Shape of Sx: " + str(x.shape))
    print("Shape of Sx1: " + str(x1.shape))
    print("Shape of Sx2: " + str(x2.shape))


    unmapped_len1 = int(0.15 * (x1.shape[2] / 1.3))
    grid_len1 = int((x1.shape[2] - 2 * unmapped_len1) / 5)

    unmapped_len2 = int(0.15 * (x2.shape[2] / 1.3))
    grid_len2 = int((x2.shape[2] - 2 * unmapped_len2) / 5)

    left1 = Lambda(lambda x1: x1[..., :, : unmapped_len1], name='left1')(x1)
    center1 = Lambda(lambda x1: x1[..., :, unmapped_len1 : x1.shape[2] - unmapped_len1], name='center1')(x1)
    right1 = Lambda(lambda x1: x1[..., :, x1.shape[2] - unmapped_len1 :], name='right1')(x1)

    left2 = Lambda(lambda x2: x2[..., :, : unmapped_len2], name='left2')(x2)
    center2 = Lambda(lambda x2: x2[..., :, unmapped_len2 : x2.shape[2] - unmapped_len2], name='center2')(x2)
    right2 = Lambda(lambda x2: x2[..., :, x2.shape[2] - unmapped_len2 :], name='right2')(x2)


    g11 = Lambda(lambda x1: x1[..., :, :grid_len1], name='g11')(center1)
    g21 = Lambda(lambda x1: x1[..., :, grid_len1:2*grid_len1], name='g21')(center1)
    g31 = Lambda(lambda x1: x1[..., :, 2*grid_len1:3*grid_len1], name='g31')(center1)
    g41 = Lambda(lambda x1: x1[..., :, 3*grid_len1:4*grid_len1], name='g41')(center1)
    g51 = Lambda(lambda x1: x1[..., :, 4*grid_len1:], name='g51')(center1)


    leftav1 = tf.keras.backend.max(left1, axis=2)
    g1av1   = tf.keras.backend.max(g11, axis=2)
    g2av1   = tf.keras.backend.max(g21, axis=2)
    g3av1   = tf.keras.backend.max(g31, axis=2)
    g4av1   = tf.keras.backend.max(g41, axis=2)
    g5av1   = tf.keras.backend.max(g51, axis=2)
    rightav1 = tf.keras.backend.max(right1, axis=2)


    g12 = Lambda(lambda x2: x2[..., :, :grid_len2], name='g12')(center2)
    g22 = Lambda(lambda x2: x2[..., :, grid_len2:2*grid_len2], name='g22')(center2)
    g32 = Lambda(lambda x2: x2[..., :, 2*grid_len2:3*grid_len2], name='g32')(center2)
    g42 = Lambda(lambda x2: x2[..., :, 3*grid_len2:4*grid_len2], name='g42')(center2)
    g52 = Lambda(lambda x2: x2[..., :, 4*grid_len2:], name='g52')(center2)


    leftav2 = tf.keras.backend.max(left2, axis=2)
    g1av2   = tf.keras.backend.max(g12, axis=2)
    g2av2   = tf.keras.backend.max(g22, axis=2)
    g3av2   = tf.keras.backend.max(g32, axis=2)
    g4av2   = tf.keras.backend.max(g42, axis=2)
    g5av2   = tf.keras.backend.max(g52, axis=2)
    rightav2 = tf.keras.backend.max(right2, axis=2)

    
    
    x_type = tf.concat([(g1av1-leftav1), (g2av1-leftav1), (g3av1-g1av1), (g4av1-g2av1), (g5av1-g3av1), (rightav1-g4av1), (rightav1-g5av1), (g1av2-leftav2), (g2av2-leftav2), (g3av2-g1av2), (g4av2-g2av2), (g5av2-g3av2), (rightav2-g4av2), (rightav2-g5av2) ], axis=1)


    x_class = tf.concat([leftav1, g1av1, g2av1, g3av1, g4av1, g5av1, rightav1], axis=1)


    x_type = Flatten()(x_type)
    x_class = Flatten()(x_class)



    model = Model(inputs = input, outputs=[x_type, x_class])

    return model

# %%
tf.keras.backend.clear_session()

scattering_extract = buildBaseScattering_hybrid2(X_all.shape[1])
scattering_extract.summary()
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 110, 17), dtype=tf.float32, name=None), name='scattering1d/Reshape_220:0', description="created by layer 'scattering1d'")
# (None, 110, 17)
# Shape of Sx: (None, 110, 17)
# Shape of Sx1: (None, 20, 17)
# Shape of Sx2: (None, 89, 17)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 16640)]      0
# __________________________________________________________________________________________________
# scattering1d (Scattering1D)     (None, 110, 17)      0           input_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 20, 17)       0           scattering1d[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1 (Sli (None, 89, 17)       0           scattering1d[0][0]
# __________________________________________________________________________________________________
# center1 (Lambda)                (None, 20, 15)       0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# center2 (Lambda)                (None, 89, 15)       0           tf.__operators__.getitem_1[0][0]
# __________________________________________________________________________________________________
# g11 (Lambda)                    (None, 20, 3)        0           center1[0][0]
# __________________________________________________________________________________________________
# left1 (Lambda)                  (None, 20, 1)        0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# g21 (Lambda)                    (None, 20, 3)        0           center1[0][0]
# __________________________________________________________________________________________________
# g31 (Lambda)                    (None, 20, 3)        0           center1[0][0]
# __________________________________________________________________________________________________
# g41 (Lambda)                    (None, 20, 3)        0           center1[0][0]
# __________________________________________________________________________________________________
# g51 (Lambda)                    (None, 20, 3)        0           center1[0][0]
# __________________________________________________________________________________________________
# right1 (Lambda)                 (None, 20, 1)        0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# g12 (Lambda)                    (None, 89, 3)        0           center2[0][0]
# __________________________________________________________________________________________________
# left2 (Lambda)                  (None, 89, 1)        0           tf.__operators__.getitem_1[0][0]
# __________________________________________________________________________________________________
# g22 (Lambda)                    (None, 89, 3)        0           center2[0][0]
# __________________________________________________________________________________________________
# g32 (Lambda)                    (None, 89, 3)        0           center2[0][0]
# __________________________________________________________________________________________________
# g42 (Lambda)                    (None, 89, 3)        0           center2[0][0]
# __________________________________________________________________________________________________
# g52 (Lambda)                    (None, 89, 3)        0           center2[0][0]
# __________________________________________________________________________________________________
# right2 (Lambda)                 (None, 89, 1)        0           tf.__operators__.getitem_1[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max_1 (TFOpLambd (None, 20)           0           g11[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max (TFOpLambda) (None, 20)           0           left1[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max_2 (TFOpLambd (None, 20)           0           g21[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max_3 (TFOpLambd (None, 20)           0           g31[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max_4 (TFOpLambd (None, 20)           0           g41[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max_5 (TFOpLambd (None, 20)           0           g51[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max_6 (TFOpLambd (None, 20)           0           right1[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max_8 (TFOpLambd (None, 89)           0           g12[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max_7 (TFOpLambd (None, 89)           0           left2[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max_9 (TFOpLambd (None, 89)           0           g22[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max_10 (TFOpLamb (None, 89)           0           g32[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max_11 (TFOpLamb (None, 89)           0           g42[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max_12 (TFOpLamb (None, 89)           0           g52[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max_13 (TFOpLamb (None, 89)           0           right2[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   (None, 20)           0           tf.math.reduce_max_1[0][0]
#                                                                  tf.math.reduce_max[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_1 (TFOpLambda) (None, 20)           0           tf.math.reduce_max_2[0][0]
#                                                                  tf.math.reduce_max[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_2 (TFOpLambda) (None, 20)           0           tf.math.reduce_max_3[0][0]
#                                                                  tf.math.reduce_max_1[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_3 (TFOpLambda) (None, 20)           0           tf.math.reduce_max_4[0][0]
#                                                                  tf.math.reduce_max_2[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_4 (TFOpLambda) (None, 20)           0           tf.math.reduce_max_5[0][0]
#                                                                  tf.math.reduce_max_3[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_5 (TFOpLambda) (None, 20)           0           tf.math.reduce_max_6[0][0]
#                                                                  tf.math.reduce_max_4[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_6 (TFOpLambda) (None, 20)           0           tf.math.reduce_max_6[0][0]
#                                                                  tf.math.reduce_max_5[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_7 (TFOpLambda) (None, 89)           0           tf.math.reduce_max_8[0][0]
#                                                                  tf.math.reduce_max_7[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_8 (TFOpLambda) (None, 89)           0           tf.math.reduce_max_9[0][0]
#                                                                  tf.math.reduce_max_7[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_9 (TFOpLambda) (None, 89)           0           tf.math.reduce_max_10[0][0]
#                                                                  tf.math.reduce_max_8[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_10 (TFOpLambda (None, 89)           0           tf.math.reduce_max_11[0][0]
#                                                                  tf.math.reduce_max_9[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_11 (TFOpLambda (None, 89)           0           tf.math.reduce_max_12[0][0]
#                                                                  tf.math.reduce_max_10[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_12 (TFOpLambda (None, 89)           0           tf.math.reduce_max_13[0][0]
#                                                                  tf.math.reduce_max_11[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_13 (TFOpLambda (None, 89)           0           tf.math.reduce_max_13[0][0]
#                                                                  tf.math.reduce_max_12[0][0]
# __________________________________________________________________________________________________
# tf.concat (TFOpLambda)          (None, 763)          0           tf.math.subtract[0][0]
#                                                                  tf.math.subtract_1[0][0]
#                                                                  tf.math.subtract_2[0][0]
#                                                                  tf.math.subtract_3[0][0]
#                                                                  tf.math.subtract_4[0][0]
#                                                                  tf.math.subtract_5[0][0]
#                                                                  tf.math.subtract_6[0][0]
#                                                                  tf.math.subtract_7[0][0]
#                                                                  tf.math.subtract_8[0][0]
#                                                                  tf.math.subtract_9[0][0]
#                                                                  tf.math.subtract_10[0][0]
#                                                                  tf.math.subtract_11[0][0]
#                                                                  tf.math.subtract_12[0][0]
#                                                                  tf.math.subtract_13[0][0]
# __________________________________________________________________________________________________
# tf.concat_1 (TFOpLambda)        (None, 140)          0           tf.math.reduce_max[0][0]
#                                                                  tf.math.reduce_max_1[0][0]
#                                                                  tf.math.reduce_max_2[0][0]
#                                                                  tf.math.reduce_max_3[0][0]
#                                                                  tf.math.reduce_max_4[0][0]
#                                                                  tf.math.reduce_max_5[0][0]
#                                                                  tf.math.reduce_max_6[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 763)          0           tf.concat[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 140)          0           tf.concat_1[0][0]
# ==================================================================================================
# Total params: 0
# Trainable params: 0
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
root_folder_path = './' + configs["TESTS_FOLDER"] + 'Hybrid2_P' + str(int(configs["PERCENTUAL"]*100)) + '_J' + str(J) + '_Q' + str(Q) + '/'

print(root_folder_path)

try:
   os.mkdir(root_folder_path)
   print("Folder Created")
except:
   pass

scattering_extract.save(root_folder_path + 'scattering_model.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ./drive/MyDrive/Scattering_Novo/results_second_order/Hybrid2_P25_J10_Q2/

# %% [markdown]
# ## Treinamento

# %%
fold = 0
mskf = MultilabelStratifiedKFold(n_splits=10, shuffle=True, random_state=42)
strat_classes = np.max(yclass_all, axis=1)
print(strat_classes.shape)


for train_index, validation_index in mskf.split(X_all, strat_classes):
    fold += 1

    if fold != 9:
        continue

    print(f"---------- FOLD {fold} -------------")

    scaler = MaxAbsScaler()
    scaler.fit(np.squeeze(X_all[train_index], axis=2))
    x_train_class = np.expand_dims(scaler.transform(np.squeeze(X_all[train_index], axis=2)), axis=2)
    x_validation_class = np.expand_dims(scaler.transform(np.squeeze(X_all[validation_index], axis=2)), axis=2)
    
    print("x_train shape: ", x_train_class.shape)
    
    x_train_type, x_train_class = scattering_extract.predict(x_train_class)
    x_validation_type, x_validation_class = scattering_extract.predict(x_validation_class)

    # Normalizing
 
    transformer = MaxAbsScaler().fit(x_train_type)
    x_train_type = transformer.transform(x_train_type)
    
    transformer = MaxAbsScaler().fit(x_train_class)
    x_train_class = transformer.transform(x_train_class)

    transformer = MaxAbsScaler().fit(x_validation_type)
    x_validation_type = transformer.transform(x_validation_type)

    transformer = MaxAbsScaler().fit(x_validation_class)
    x_validation_class = transformer.transform(x_validation_class)

    print("Size of extracted classification features: ",x_train_class.shape)
    print("Size of extracted type features: ",x_train_type.shape)

    y_train, y_validation = {}, {}
    y_train["detection"] = ydet_all[train_index]
    y_validation["detection"] = ydet_all[validation_index]
    y_train["type"] = ytype_all[train_index]
    y_validation["type"] = ytype_all[validation_index]
    y_train["classification"] = yclass_all[train_index]
    y_validation["classification"] = yclass_all[validation_index]

    yclass_weights = calculating_class_weights(np.max(y_train["classification"], axis=1))

    print(yclass_weights)
    
    folderPath = root_folder_path + str(fold) + "/"
    try:
        os.mkdir(folderPath)
    except:
        pass

    try:
        os.mkdir('./' + root_folder_path + 'logs')
    except:
        pass

    np.save(folderPath + "train_index.npy", train_index)
    np.save(folderPath + "validation_index.npy", validation_index)
    

    #tensorboard_callback = TensorBoard(log_dir='./' + configs["FOLDER_PATH"] + '/logs')
    tensorboard_callback = TensorBoard(log_dir='./' + root_folder_path + 'logs')

    # early_stopping_callback = EarlyStopping(monitor='val_loss', patience=50, verbose=True, restore_best_weights=True)

    if configs["INITIAL_EPOCH"] > 0:
        model = ModelHandler.loadModel(folderPath + 'model_{0}.h5'.format(configs["INITIAL_EPOCH"]))
    else:
        model = modelHandler.buildScatteringOutput_hybrid(input_class_shape=x_train_class.shape[1], input_type_shape=x_train_type.shape[1]) # Perceba que aqui a função de construção foi alterada
 
    model.summary()
 
    fileEpoch = configs["INITIAL_EPOCH"]
    while fileEpoch < configs["TOTAL_MAX_EPOCHS"]:
        fileEpoch += configs["N_EPOCHS_TRAINING"]      

        if not os.path.isfile(folderPath + 'model_without_detection.h5'):
            for subtask in ['type', 'classification']:
                print(f"FOLD {fold}: Training {subtask}")
                
                freeze(model, task_name=subtask)
                model.compile(optimizer = Adam(), \
                            #   loss = [ModelHandler.sumSquaredError, "categorical_crossentropy", ModelHandler.get_bce_weighted_loss(yclass_weights)], \
                            #   loss = [ModelHandler.sumSquaredError, "categorical_crossentropy", "binary_crossentropy"], \
                              loss = ["categorical_crossentropy", "binary_crossentropy"], \
                              metrics=[['categorical_accuracy'], ['binary_accuracy']])
                
                early_stopping_callback = EarlyStopping(monitor=f"val_{subtask}_loss", patience=50, verbose=True, restore_best_weights=True)
                #hist_opt = model.fit(x=x_train, y=[y_train["type"], y_train["classification"]], \
                #                    validation_data=(x_validation, [y_validation["type"], y_validation["classification"]]), \
                #                    epochs=configs["N_EPOCHS_TRAINING"], verbose=2, callbacks=[early_stopping_callback, tensorboard_callback], batch_size=32)
                hist_opt = model.fit(x=[x_train_type, x_train_class], y=[y_train["type"], y_train["classification"]], \
                                    validation_data=([x_validation_type, x_validation_class], [y_validation["type"], y_validation["classification"]]), \
                                    epochs=configs["N_EPOCHS_TRAINING"], verbose=2, callbacks=[early_stopping_callback, tensorboard_callback], batch_size=32)
                
                   
            model.save(folderPath + 'model_without_detection.h5')
  
    del model, y_train, x_train_type, x_train_class, x_validation_type, x_validation_class
# Out:
# (1892, 26)
# ---------- FOLD 9 -------------
# x_train shape:  (1700, 16640, 1)
# Size of extracted classification features:  (1700, 140)
# Size of extracted type features:  (1700, 763)
# [[ 0.60757684  2.82392027]
#  [ 0.58864266  3.3203125 ]
#  [ 0.50655542 38.63636364]
#  [ 0.50595238 42.5       ]
#  [ 0.50655542 38.63636364]
#  [ 0.50837321 30.35714286]
#  [ 0.50415184 60.71428571]
#  [ 0.63909774  2.2972973 ]
#  [ 0.51020408 25.        ]
#  [ 0.5056514  44.73684211]
#  [ 0.50898204 28.33333333]
#  [ 0.63150074  2.40112994]
#  [ 0.57123656  4.00943396]
#  [ 0.54382598  6.20437956]
#  [ 0.50595238 42.5       ]
#  [ 0.50776583 32.69230769]
#  [ 0.54487179  6.07142857]
#  [ 0.5071599  35.41666667]
#  [ 0.50655542 38.63636364]
#  [ 0.50806934 31.48148148]
#  [ 0.5071599  35.41666667]
#  [ 0.50776583 32.69230769]
#  [ 0.5071599  35.41666667]
#  [ 0.51020408 25.        ]
#  [ 0.50776583 32.69230769]
#  [ 0.5071599  35.41666667]]
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 763)]        0
# __________________________________________________________________________________________________
# type_dense_0 (Dense)            (None, 200)          152800      input_5[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 140)]        0
# __________________________________________________________________________________________________
# type_leaky_0 (LeakyReLU)        (None, 200)          0           type_dense_0[0][0]
# __________________________________________________________________________________________________
# classification_dense_0 (Dense)  (None, 300)          42300       input_4[0][0]
# __________________________________________________________________________________________________
# type_dropout (Dropout)          (None, 200)          0           type_leaky_0[0][0]
# __________________________________________________________________________________________________
# classification_leaky_0 (LeakyRe (None, 300)          0           classification_dense_0[0][0]
# __________________________________________________________________________________________________
# type_dense_1 (Dense)            (None, 200)          40200       type_dropout[0][0]
# __________________________________________________________________________________________________
# classification_dropout (Dropout (None, 300)          0           classification_leaky_0[0][0]
# __________________________________________________________________________________________________
# type_leaky_1 (LeakyReLU)        (None, 200)          0           type_dense_1[0][0]
# __________________________________________________________________________________________________
# classification_dense_1 (Dense)  (None, 300)          90300       classification_dropout[0][0]
# __________________________________________________________________________________________________
# type_dense_2 (Dense)            (None, 15)           3015        type_leaky_1[0][0]
# __________________________________________________________________________________________________
# classification_leaky_1 (LeakyRe (None, 300)          0           classification_dense_1[0][0]
# __________________________________________________________________________________________________
# type_2 (Reshape)                (None, 5, 3)         0           type_dense_2[0][0]
# __________________________________________________________________________________________________
# classification_dense_2 (Dense)  (None, 130)          39130       classification_leaky_1[0][0]
# __________________________________________________________________________________________________
# type (Softmax)                  (None, 5, 3)         0           type_2[0][0]
# __________________________________________________________________________________________________
# classification (Reshape)        (None, 5, 26)        0           classification_dense_2[0][0]
# ==================================================================================================
# Total params: 367,745
# Trainable params: 367,745
# Non-trainable params: 0
# __________________________________________________________________________________________________
# FOLD 9: Training type
# input_5 False
# type_dense_0 True
# input_4 False
# type_leaky_0 True
# classification_dense_0 False
# type_dropout True
# classification_leaky_0 False
# type_dense_1 True
# classification_dropout False
# type_leaky_1 True
# classification_dense_1 False
# type_dense_2 True
# classification_leaky_1 False
# type_2 True
# classification_dense_2 False
# type True
# classification False
# Epoch 1/500
# 54/54 - 3s - loss: 1.3113 - type_loss: 0.6131 - classification_loss: 0.6982 - type_categorical_accuracy: 0.8196 - classification_binary_accuracy: 0.4548 - val_loss: 1.0646 - val_type_loss: 0.3663 - val_classification_loss: 0.6983 - val_type_categorical_accuracy: 0.8562 - val_classification_binary_accuracy: 0.4558
# Epoch 2/500
# 54/54 - 0s - loss: 1.0200 - type_loss: 0.3219 - classification_loss: 0.6981 - type_categorical_accuracy: 0.8687 - classification_binary_accuracy: 0.4575 - val_loss: 0.9635 - val_type_loss: 0.2652 - val_classification_loss: 0.6983 - val_type_categorical_accuracy: 0.8906 - val_classification_binary_accuracy: 0.4558
# Epoch 3/500
# 54/54 - 0s - loss: 0.9644 - type_loss: 0.2662 - classification_loss: 0.6982 - type_categorical_accuracy: 0.8941 - classification_binary_accuracy: 0.4556 - val_loss: 0.9462 - val_type_loss: 0.2479 - val_classification_loss: 0.6983 - val_type_categorical_accuracy: 0.9083 - val_classification_binary_accuracy: 0.4558
# Epoch 4/500
# 54/54 - 0s - loss: 0.9348 - type_loss: 0.2367 - classification_loss: 0.6981 - type_categorical_accuracy: 0.9076 - classification_binary_accuracy: 0.4574 - val_loss: 0.9075 - val_type_loss: 0.2092 - val_classification_loss: 0.6983 - val_type_categorical_accuracy: 0.9323 - val_classification_binary_accuracy: 0.4558
# Epoch 5/500
# 54/54 - 0s - loss: 0.9228 - type_loss: 0.2246 - classification_loss: 0.6981 - type_categorical_accuracy: 0.9158 - classification_binary_accuracy: 0.4568 - val_loss: 0.8894 - val_type_loss: 0.1911 - val_classification_loss: 0.6983 - val_type_categorical_accuracy: 0.
- val_classification_loss: 0.6983 - val_type_categorical_accuracy: 0.9740 - val_classification_binary_accuracy: 0.4558
# Epoch 102/500
# 54/54 - 0s - loss: 0.7195 - type_loss: 0.0213 - classification_loss: 0.6982 - type_categorical_accuracy: 0.9961 - classification_binary_accuracy: 0.4565 - val_loss: 0.8094 - val_type_loss: 0.1111 - val_classification_loss: 0.6983 - val_type_categorical_accuracy: 0.9719 - val_classification_binary_accuracy: 0.4558
# Epoch 103/500
# 54/54 - 0s - loss: 0.7170 - type_loss: 0.0188 - classification_loss: 0.6982 - type_categorical_accuracy: 0.9956 - classification_binary_accuracy: 0.4566 - val_loss: 0.8368 - val_type_loss: 0.1385 - val_classification_loss: 0.6983 - val_type_categorical_accuracy: 0.9708 - val_classification_binary_accuracy: 0.4558
# Restoring model weights from the end of the best epoch.
# Epoch 00103: early stopping
# FOLD 9: Training classification
# input_5 False
# type_dense_0 False
# input_4 False
# type_leaky_0 False
# classification_dense_0 True
# type_dropout False
# classification_leaky_0 True
# type_dense_1 False
# classification_dropout True
# type_leaky_1 False
# classification_dense_1 True
# type_dense_2 False
# classification_leaky_1 True
# type_2 False
# classification_dense_2 True
# type False
# classification True
# Epoch 1/500
# 54/54 - 1s - loss: 0.3890 - type_loss: 0.0522 - classification_loss: 0.3368 - type_categorical_accuracy: 0.9845 - classification_binary_accuracy: 0.9325 - val_loss: 0.2727 - val_type_loss: 0.0802 - val_classification_loss: 0.1926 - val_type_categorical_accuracy: 0.9698 - val_classification_binary_accuracy: 0.9663
# Epoch 2/500
# 54/54 - 0s - loss: 0.2179 - type_loss: 0.0495 - classification_loss: 0.1684 - type_categorical_accuracy: 0.9860 - classification_binary_accuracy: 0.9650 - val_loss: 0.2377 - val_type_loss: 0.0802 - val_classification_loss: 0.1575 - val_type_categorical_accuracy: 0.9698 - val_classification_binary_accuracy: 0.9663
# Epoch 3/500
# 54/54 - 0s - loss: 0.1729 - type_loss: 0.0457 - classification_loss: 0.1272 - type_categorical_accuracy: 0.9859 - classification_binary_accuracy: 0.9650 - val_loss: 0.1909 - val_type_loss: 0.0802 - val_classification_loss: 0.1108 - val_type_categorical_accuracy: 0.9698 - val_classification_binary_accuracy: 0.9661
# Epoch 4/500
# 54/54 - 0s - loss: 0.1530 - type_loss: 0.0468 - classification_loss: 0.1062 - type_categorical_accuracy: 0.9884 - classification_binary_accuracy: 0.9652 - val_loss: 0.1750 - val_type_loss: 0.0802 - val_classification_loss: 0.0948 - val_type_categorical_accuracy: 0.9698 - val_classification_binary_accuracy: 0.9670
# Epoch 5/500
# 54/54 - 0s - loss: 0.1419 - type_loss: 0.0474 - classification_loss: 0.0946 - type_categorical_accuracy: 0.9846 - classification_binary_accuracy: 0.9657 - val_loss: 0.1642 - val_type_loss: 0.0802 - val_classification_loss: 0.0840 - val_type_categorical_accuracy: 0.9698 - val_classification_binary_accuracy: 0.9673
# Epoch 6/500
# 54/54 - 0s - loss: 0.1424 - type_loss: 0.0559 - classification_loss: 0.0865 - type_categorical_accuracy: 0.9861 - classification_binary_accuracy: 0.9674 - val_loss: 0.1591 - val_type_loss: 0.0802 - val_classification_loss: 0.0790 - val_type_categorical_accuracy: 0.9698 - val_classification_binary_accuracy: 0.9697
# Epoch 7/500
# 54/54 - 0s - loss: 0.1334 - type_loss: 0.0522 - classification_loss: 0.0812 - type_categorical_accuracy: 0.9852 - classification_binary_accuracy: 0.9690 - val_loss: 0.1565 - val_type_loss: 0.0802 - val_classification_loss: 0.0763 - val_type_categorical_accuracy: 0.9698 - val_classification_binary_accuracy: 0.